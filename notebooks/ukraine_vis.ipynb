# %%
# !pip install -r requirements.txt
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp39-cp39-macosx_11_0_arm64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 20.4 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: plotly in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (5.14.1)
# Collecting wordcloud
#   Using cached wordcloud-1.9.2.tar.gz (222 kB)
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp39-cp39-macosx_11_0_arm64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 22.5 MB/s eta 0:00:00a 0:00:01
# Collecting folium
#   Using cached folium-0.14.0-py2.py3-none-any.whl (102 kB)
# Collecting sklearn
#   Using cached sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.7-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 13.1 MB/s eta 0:00:00
# Collecting numpy>=1.20.3
#   Downloading numpy-1.25.0-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 19.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from plotly->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from plotly->-r requirements.txt (line 2)) (8.2.2)
# Collecting pillow
#   Downloading Pillow-10.0.0-cp39-cp39-macosx_11_0_arm64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.8 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp39-cp39-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 7.6 MB/s eta 0:00:00
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.40.0-cp39-cp39-macosx_10_9_universal2.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 20.2 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp39-cp39-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.6/229.6 kB 14.1 MB/s eta 0:00:00
# Collecting pyparsing<3.1,>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting branca>=0.6.0
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from folium->-r requirements.txt (line 5)) (3.1.2)
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 10.6 MB/s eta 0:00:00
# Collecting scikit-learn>=1.0.0
#   Downloading scikit_learn-1.3.0-cp39-cp39-macosx_12_0_arm64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 23.4 MB/s eta 0:00:00a 0:00:01
# Collecting numexpr
#   Downloading numexpr-2.8.4-cp39-cp39-macosx_11_0_arm64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 9.0 MB/s eta 0:00:00
# Collecting gensim
#   Downloading gensim-4.3.1-cp39-cp39-macosx_11_0_arm64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 22.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from pyLDAvis->-r requirements.txt (line 7)) (65.6.3)
# Collecting funcy
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting scipy
#   Downloading scipy-1.11.1-cp39-cp39-macosx_12_0_arm64.whl (29.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 21.8 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 8)) (5.9.0)
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 8)) (8.14.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 8)) (6.15.0)
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 4)) (3.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (5.9.0)
# Requirement already satisfied: appnope in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (7.3.4)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (6.1)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.6.2)
# Requirement already satisfied: backcall in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (3.0.39)
# Requirement already satisfied: typing-extensions in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (4.7.1)
# Requirement already satisfied: pickleshare in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from requests->folium->-r requirements.txt (line 5)) (2023.5.7)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.3-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 12.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-macosx_11_0_arm64.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.0/123.0 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (5.3.0)
# Requirement already satisfied: entrypoints in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.2.6)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/anaconda3/envs/projekt_vis/lib/python3.9/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements.txt (line 8)) (3.8.0)
# Building wheels for collected packages: wordcloud, sklearn
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp39-cp39-macosx_11_0_arm64.whl size=153376 sha256=8796b8510c51741449ab75546673ceddf5c43795fe265d592955c2187567e5f7
#   Stored in directory: /Users/konstantinwitossek/Library/Caches/pip/wheels/fd/79/b1/1e0a49160de8dfb17c54736cc73759e1d26f9343b61c0d5441
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2951 sha256=e420a14732d824c546ddcd32530721f71eb5111c7a8c51a5c4ac8b5f53633f65
#   Stored in directory: /Users/konstantinwitossek/Library/Caches/pip/wheels/36/49/c9/2374f1dee1b599effabf63d948635e6608f62d0ccde027b7e2
# Successfully built wordcloud sklearn
# Installing collected packages: sklearn, pytz, funcy, widgetsnbextension, urllib3, tzdata, threadpoolctl, smart-open, pyparsing, pillow, numpy, kiwisolver, jupyterlab-widgets, joblib, importlib-resources, idna, fonttools, cycler, charset-normalizer, scipy, requests, pandas, numexpr, contourpy, branca, scikit-learn, matplotlib, gensim, folium, wordcloud, pyLDAvis, ipywidgets
# Successfully installed branca-0.6.0 charset-normalizer-3.1.0 contourpy-1.1.0 cycler-0.11.0 folium-0.14.0 fonttools-4.40.0 funcy-2.0 gensim-4.3.1 idna-3.4 importlib-resources-5.12.0 ipywidgets-8.0.7 joblib-1.3.1 jupyterlab-widgets-3.0.8 kiwisolver-1.4.4 matplotlib-3.7.2 numexpr-2.8.4 numpy-1.25.0 pandas-2.0.3 pillow-10.0.0 pyLDAvis-3.4.1 pyparsing-3.0.9 pytz-2023.3 requests-2.31.0 scikit-learn-1.3.0 scipy-1.11.1 sklearn-0.0.post5 smart-open-6.3.0 threadpoolctl-3.1.0 tzdata-2023.3 urllib3-2.0.3 widgetsnbextension-4.0.8 wordcloud-1.9.2

# %%
# Import necessary libraries
import pandas as pd
import plotly.express as px
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from collections import Counter
import re
import plotly.io as pio
import plotly.graph_objects as go
import folium
import json
import base64

from folium.plugins import TimestampedGeoJson
from folium.plugins import HeatMapWithTime

# %%
data_folder = "./data/"

# %%
# Read CSV file
df = pd.read_csv(data_folder + 'ukr-civharm-2023-05-25.csv')  # replace 'your_file.csv' with your file name
print(df.head())
# Out:
#         id        date   latitude  longitude                   location  \
# 0  CIV0001  02/24/2022  49.850050  36.659031  Chuhuiv, south of Kharkiv
# 1  CIV0002  02/24/2022  48.748564  30.218515                       Uman
# 2  CIV0003  02/24/2022  50.470055  30.527381                       Kyiv
# 3  CIV0004  02/24/2022  47.775537  37.239601                   Vuhledar
# 4  CIV0007  02/24/2022  46.227890  34.642830        Semihatka/Henichesk
#
#                                          description  \
# 0  Apartment block hit. Crater is very large, pos...
# 1  Civilians hit by what appears to have been art...
# 2    Explosion in central Kyiv, nothing further yet.
# 3    Explosion in central Kyiv, nothing further yet.
# 4  [Graphic: Image shows a dead child wrapped in ...
#
#                                              sources  \
# 0  https://twitter.com/Michael1Sheldon/status/149...
# 1  https://twitter.com/ragipsoylu/status/14967372...
# 2  https://twitter.com/FannyFacsar/status/1496787...
# 3  https://twitter.com/IBN_MOHAMMAD/status/149677...
# 4  https://twitter.com/GayanaYuksel/status/149683...
#
#                                         associations
# 0  Type of area affected=Residential,Weapon Syste...
# 1  Type of area affected=Commercial,Weapon System...
# 2  Type of area affected=Undefined,Weapon System=...
# 3  Type of area affected=Healthcare,Weapon System...
# 4  Type of area affected=Undefined,Weapon System=...

# %%
df['date'] = pd.to_datetime(df['date'])

# Dataframe nach Werten des Datums sortieren
df_sorted = df.sort_values('date')

# Spalte cumulative_count', die die kumulative Anzahl der Ereignisse darstellt
df_sorted['cumulative_count'] = range(1, len(df_sorted) + 1)

# Erstellen Diagramm mit den kumulierten Daten
fig = px.line(df_sorted, x='date', y='cumulative_count', title='Cumulative Number of Incidents Over Time')

# Tickformat der X-Achse anpassen
fig.update_xaxes(
    dtick="M1",  # Monatliche Ticks
    tickformat="%b\n%Y"  # Format: "Mon\nJahr"
)

fig.show()

pio.write_html(fig, file="line_chart1.html", auto_open=True)

# %%
# Create map showing location of incidents
fig = px.scatter_geo(df, lat='latitude', lon='longitude', hover_name='location', title='Location of Incidents')
fig.show()
pio.write_html(fig, file="map1.html", auto_open=True)

# %%
fig = go.Figure(data=go.Scattergeo(
    lat = df['latitude'],
    lon = df['longitude'],
    mode = 'markers',
    text = df['location'],
))

fig.update_geos(
    resolution=50,
    showland=True,
    landcolor="rgb(204, 204, 204)",
    countrycolor="rgb(204, 204, 204)",
    lakecolor="rgb(255, 255, 255)",
    projection_type="equirectangular",
    center=dict(lat=48.3794, lon=31.1656),  # center on Ukraine
    lonaxis_range=[22, 40],  # longitude range for Ukraine
    lataxis_range=[44, 52],  # latitude range for Ukraine
    showcountries=True,  # show country borders
)

fig.update_layout(
    title_text = 'Location of Incidents',
)

fig.show()
pio.write_html(fig, file="map2.html", auto_open=True)

# %%
## Map with Folium

# Initialize map with focus on Ukraine
m = folium.Map(location=[48.3794, 31.1656], zoom_start=6)

# Add points to the map
for idx, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['location']).add_to(m)

# Display the map
m

# %%
#map with gejson
# Lesen GeoJSON-Datei
with open('./data/geoBoundaries-UKR-ADM1_simplified.geojson') as f:
    ukraine_geojson = json.load(f)

# Erstellen Karte
fig = go.Figure(data=go.Scattergeo(
    lat = df['latitude'],
    lon = df['longitude'],
    mode = 'markers',
    text = df['location'],
))

# GeoJSON-Daten hinzufügen
fig.update_geos(
    visible=False, 
    resolution=50, 
    showcountries=True, 
    countrycolor="Black",
    showcoastlines=True, 
    coastlinecolor="RebeccaPurple",
    showland=True, 
    landcolor="LightGreen",
    showocean=True, 
    oceancolor="Azure",
    lakecolor="Azure",
    projection_type="natural earth"
)

fig.add_trace(
    go.Choropleth(
        geojson = ukraine_geojson,
        locations = ['UKR'], # ISO 3166-1 alpha-3 code
        z = [1],  # to control color
        colorscale = [[0, 'rgba(0, 0, 0, 0)'], [1, 'rgba(0, 0, 0, 0)']],
        showscale = False,  # we don't need colorbar
        hoverinfo='skip',  # no hover info
        marker_line_width = 2,  # border line width
        marker_line_color = 'red'  # border line color
    )
)

fig.update_layout(
    title_text = 'Location of Incidents',
    geo=dict(showframe=False, showcoastlines=False, projection_type='equirectangular'),
)

fig.show()

pio.write_html(fig, file="map3.html", auto_open=True)

# %%
with open('./data/geoBoundaries-UKR-ADM1_simplified.geojson') as f:
    ukraine_geojson = json.load(f)

# Zentrieren Karte auf durchschnittlichen Koordinaten
average_lat = df['latitude'].mean()
average_lon = df['longitude'].mean()

m = folium.Map(location=[average_lat, average_lon], zoom_start=6)

# Marker basierend auf den Datenpunkten
for idx, row in df.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']], popup=row['location']).add_to(m)

folium.GeoJson(
    ukraine_geojson,
    name='ukraine'
).add_to(m)

m.save('folium_map1.html')
m

# %%
df['date'] = pd.to_datetime(df['date'])

fig = px.scatter_geo(df,
                     lat='latitude',
                     lon='longitude',
                     animation_frame='date',
                     title='Ereignisse im Laufe der Zeit')

fig.update_geos(showcountries=True, countrycolor="Black",
                showsubunits=True, subunitcolor="Blue")

fig.show()
pio.write_html(fig, file="map4.html", auto_open=True)

# %%
df = df
df['date'] = pd.to_datetime(df['date'])

with open('./data/geoBoundaries-UKR-ADM1_simplified.geojson') as f:
    ukraine_geojson = json.load(f)

df.sort_values('date', inplace=True)

# Erstellen Liste von Daten für jede Zeiteinheit
index_range = pd.date_range(start=df.date.min(), end=df.date.max(), freq='D')
data = []
for date in index_range:
    tmp_df = df[df.date <= date]
    data.append(tmp_df[['latitude', 'longitude']].groupby(['latitude', 'longitude']).size().reset_index().values.tolist())

# Erstellen der Karte
m = folium.Map(location=[48.3794, 31.1656], zoom_start=6)

# GeoJSON-Datei der Ukraine
ukraine_geo = ukraine_geojson  # Pfad zur GeoJSON-Datei

folium.GeoJson(
    ukraine_geo,
    name='ukraine'
).add_to(m)

# HeatMapWithTime-Objekt zur Karte hinzufügen
HeatMapWithTime(data, auto_play=True, max_opacity=0.8, speed_step=1/5, min_speed=30).add_to(m)

# 
m.save('folium_map2.html')
m

# %%
# Transformiere 'date' Spalte in datetime-Format
data['date'] = pd.to_datetime(data['date'])

# Extrahiere den Angriffstyp aus der 'associations'-Spalte
data['attack_type'] = data['associations'].str.split('Weapon System=').str[-1]

# Erstelle eine Karte
m = folium.Map(location=[48.3794, 31.1656], zoom_start=5)

# Erstelle für jeden Angriffstyp eine eigene FeatureGroup
attack_types = data['attack_type'].unique()

for attack_type in attack_types:
    fg = folium.FeatureGroup(name=attack_type)
    
    attack_data = data[data['attack_type'] == attack_type]
    
    for _, row in attack_data.iterrows():
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=5,
            color="red",
            fill=True,
            fill_opacity=0.6
        ).add_to(fg)
    
    fg.add_to(m)

folium.LayerControl().add_to(m)

# %%
# Prepare text data for word cloud
df['description'] = df['description'].apply(lambda x: ' '.join(re.sub(r'[^a-zA-Z]',' ',x).split()))
text = ' '.join(df['description'])

# WordCloud erstellen
wordcloud = WordCloud(width = 1000, height = 500).generate(text)

# Plot
fig = plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis('off')

# Speichern als PNG
fig.savefig("wordcloud.png", dpi=1800, bbox_inches='tight')

plt.close(fig)

# %%
from collections import Counter
import json

# Berechne Wortfrequenzen
words = text.split()
word_frequencies = Counter(words)

# Konvertiere in Liste von Dictionaries
word_frequencies = [{'text': word, 'size': freq} for word, freq in word_frequencies.items()]

# Speichern als JSON
with open('word_frequencies.json', 'w') as f:
    json.dump(word_frequencies, f)

# %%
png_file = './wordcloud.png'
# Einlesen der PNG Datei und Konvertierung zu Base64
with open(png_file, "rb") as img_file:
    b64_string = base64.b64encode(img_file.read()).decode()

# Erstellen des HTML Strings
html_string = f"""
<!DOCTYPE html>
<html>
<body>

<h1>My WordCloud</h1>

<img src="data:image/png;base64,{b64_string}" alt="Wordcloud" style="width: 100%;">

</body>
</html>
"""

# Speichern als HTML
with open("wordcloud1.html", "w") as html_file:
    html_file.write(html_string)

# %%
# Prepare associations data for word cloud
df['associations'] = df['associations'].apply(lambda x: ' '.join(re.sub(r'[^a-zA-Z]', ' ', x).split()))
associations_text = ' '.join(df['associations'])

# %%
# Generate word cloud for associations
wordcloud = WordCloud(width = 1000, height = 500).generate(associations_text)

fig = plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# Speichern als PNG
fig.savefig("wordcloud2.png", dpi=1800, bbox_inches='tight')
plt.close(fig)

# %%
png_file = './wordcloud2.png'
# Einlesen der PNG Datei und Konvertierung zu Base64
with open(png_file, "rb") as img_file:
    b64_string = base64.b64encode(img_file.read()).decode()

# Erstellen des HTML Strings
html_string = f"""
<!DOCTYPE html>
<html>
<body>

<h1>My WordCloud</h1>

<img src="data:image/png;base64,{b64_string}" alt="Wordcloud" style="width: 100%;">

</body>
</html>
"""

# Speichern als HTML
with open("wordcloud2.html", "w") as html_file:
    html_file.write(html_string)
